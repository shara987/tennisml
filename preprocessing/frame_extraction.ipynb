# %%
from rembg import remove
from PIL import Image
import os
from pathlib import Path

"""
    you should download these libraries
    
    pip install pillow
    pip install rembg
    pip install onnxruntime
"""


def image_list():
    try:
        base = Path(__file__).parent
    except:
        base = Path.cwd().parent

    mock_data_path = base / "frames"

    # SORT the directory listing
    folders_list = sorted(mock_data_path.iterdir(), key=lambda p: p.name)
    return folders_list

print(image_list())
# Out:
# [WindowsPath('d:/tenis_MHacks/tennisml/frames/frame_00000.jpg'), WindowsPath('d:/tenis_MHacks/tennisml/frames/frame_00600.jpg'), WindowsPath('d:/tenis_MHacks/tennisml/frames/frame_01200.jpg'), WindowsPath('d:/tenis_MHacks/tennisml/frames/frame_01800.jpg'), WindowsPath('d:/tenis_MHacks/tennisml/frames/frame_02400.jpg'), WindowsPath('d:/tenis_MHacks/tennisml/frames/frame_03000.jpg'), WindowsPath('d:/tenis_MHacks/tennisml/frames/frame_03600.jpg'), WindowsPath('d:/tenis_MHacks/tennisml/frames/frame_04200.jpg'), WindowsPath('d:/tenis_MHacks/tennisml/frames/frame_04800.jpg'), WindowsPath('d:/tenis_MHacks/tennisml/frames/frame_05400.jpg'), WindowsPath('d:/tenis_MHacks/tennisml/frames/frame_06000.jpg'), WindowsPath('d:/tenis_MHacks/tennisml/frames/frame_06600.jpg'), WindowsPath('d:/tenis_MHacks/tennisml/frames/frame_07200.jpg'), WindowsPath('d:/tenis_MHacks/tennisml/frames/frame_07800.jpg'), WindowsPath('d:/tenis_MHacks/tennisml/frames/frame_08400.jpg'), WindowsPath('d:/tenis_MHacks/tennisml/frames/frame_09000.jpg'), WindowsPath('d:/tenis_MHacks/tennisml/frames/frame_09600.jpg'), WindowsPath('d:/tenis_MHacks/tennisml/frames/frame_10200.jpg'), WindowsPath('d:/tenis_MHacks/tennisml/frames/frame_10800.jpg'), WindowsPath('d:/tenis_MHacks/tennisml/frames/frame_11400.jpg'), WindowsPath('d:/tenis_MHacks/tennisml/frames/frame_12000.jpg'), WindowsPath('d:/tenis_MHacks/tennisml/frames/frame_12600.jpg'), WindowsPath('d:/tenis_MHacks/tennisml/frames/frame_13200.jpg'), WindowsPath('d:/tenis_MHacks/tennisml/frames/frame_13800.jpg'), WindowsPath('d:/tenis_MHacks/tennisml/frames/frame_14400.jpg'), WindowsPath('d:/tenis_MHacks/tennisml/frames/frame_15000.jpg'), WindowsPath('d:/tenis_MHacks/tennisml/frames/frame_15600.jpg'), WindowsPath('d:/tenis_MHacks/tennisml/frames/frame_16200.jpg'), WindowsPath('d:/tenis_MHacks/tennisml/frames/frame_16800.jpg'), WindowsPath('d:/tenis_MHacks/tennisml/frames/frame_17400.jpg'), WindowsPath('d:/tenis_MHacks/tennisml/frames/frame_18000.jpg'), WindowsPath('d:/tenis_MHacks/tennisml/frames/frame_18600.jpg'), WindowsPath('d:/tenis_MHacks/tennisml/frames/frame_19200.jpg'), WindowsPath('d:/tenis_MHacks/tennisml/frames/frame_19800.jpg'), WindowsPath('d:/tenis_MHacks/tennisml/frames/frame_20400.jpg'), WindowsPath('d:/tenis_MHacks/tennisml/frames/frame_21000.jpg'), WindowsPath('d:/tenis_MHacks/tennisml/frames/frame_21600.jpg'), WindowsPath('d:/tenis_MHacks/tennisml/frames/frame_22200.jpg'), WindowsPath('d:/tenis_MHacks/tennisml/frames/frame_22800.jpg'), WindowsPath('d:/tenis_MHacks/tennisml/frames/frame_23400.jpg'), WindowsPath('d:/tenis_MHacks/tennisml/frames/frame_24000.jpg'), WindowsPath('d:/tenis_MHacks/tennisml/frames/frame_24600.jpg'), WindowsPath('d:/tenis_MHacks/tennisml/frames/frame_25200.jpg'), WindowsPath('d:/tenis_MHacks/tennisml/frames/frame_25800.jpg'), WindowsPath('d:/tenis_MHacks/tennisml/frames/frame_26400.jpg'), WindowsPath('d:/tenis_MHacks/tennisml/frames/frame_27000.jpg'), WindowsPath('d:/tenis_MHacks/tennisml/frames/frame_27600.jpg'), WindowsPath('d:/tenis_MHacks/tennisml/frames/frame_28200.jpg'), WindowsPath('d:/tenis_MHacks/tennisml/frames/frame_28800.jpg')]
